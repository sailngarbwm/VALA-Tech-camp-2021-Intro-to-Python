# %% [markdown]
# ## Run these lines before the demonstration begins

# %% [markdown]
# ### If you are running a google collab notebook

# %%
# !pip install -r https://raw.githubusercontent.com/sailngarbwm/VALA-Tech-camp-2021-Intro-to-Python/main/requirements.txt
# !pip install -r requirements.txt
# Out:
# Collecting jgarber_respitch
#   Cloning git://github.com/sailngarbwm/Jgarber-respitch (to revision master) to /private/var/folders/07/8rc203z16fs7h26gb4xmv62c0000gp/T/pip-install-g8oh77gu/jgarber-respitch_6830ca82b3e14a2d8807f7a4bdfddcda
#   Running command git clone -q git://github.com/sailngarbwm/Jgarber-respitch /private/var/folders/07/8rc203z16fs7h26gb4xmv62c0000gp/T/pip-install-g8oh77gu/jgarber-respitch_6830ca82b3e14a2d8807f7a4bdfddcda
#   WARNING: Did not find branch or tag 'master', assuming revision or ref.
#   Running command git checkout -q master
#   error: pathspec 'master' did not match any file(s) known to git
# WARNING: Discarding git+git://github.com/sailngarbwm/Jgarber-respitch@master#egg=jgarber_respitch. Command errored out with exit status 1: git checkout -q master Check the logs for full command output.
# Collecting numpy==1.16.*
#   Using cached numpy-1.16.6.zip (5.1 MB)
# Requirement already satisfied: pandas==1.* in /Users/garberj/opt/anaconda3/envs/VALA/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/sailngarbwm/VALA-Tech-camp-2021-Intro-to-Python/main/requirements.txt (line 2)) (1.2.3)
# Requirement already satisfied: matplotlib==3.* in /Users/garberj/opt/anaconda3/envs/VALA/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/sailngarbwm/VALA-Tech-camp-2021-Intro-to-Python/main/requirements.txt (line 3)) (3.4.0)
# Collecting seaborn==0.8.1
#   Using cached seaborn-0.8.1-py3-none-any.whl
# ERROR: Could not find a version that satisfies the requirement jgarber-respitch (unavailable)
# ERROR: No matching distribution found for jgarber-respitch (unavailable)

# %%
from jgarber_respitch.Python_kitchen_tools_V3 import all_words

# %% [markdown]
# ### Resleads start at the next cell

# %% [markdown]
# # You Already know how to Code!
#
# ![image.png](attachment:image.png)

# %%
import numpy as np # library for mathematic analysis
b = [1,2,3]
np.mean(b)  #a function that calculates the mean

# %% [markdown]
# ## But we dont want numbers, we want Letters right?
#
#
# ### We need to make a *String*
#
#
#
# ### Python calls any bit of text a string, and it knows its a string because we put "quotation" marks around it
#
# ![image.png](attachment:image.png)

# %%
"This"

# %%
'abcd'

# %% [markdown]
# ### But what if we want to use this text again?
#
# #### if only we could *assign*  our string a nickname...... It'd be pretty Australian!!
#
# ![image.png](attachment:image.png)

# %%
Garbo = 'Jonathan Lloyd Garber'

# %%
Garbo

# %%
L = 'abcde'

# %% [markdown]
# ### Meet our magic doodad - the all_word() function!!!!
#
# This function takes in an string of letters, and prints out all of the english words that are made up from those letters
#
# **all_word(*Letters*)**
#
# #### Inputs:
#
#   ***Letters:*** a string of letters or a variable containing a string of letters
#
# #### Outputs:
#
#    A print out of every word from longest to shortest beneath our cell of code

# %%
all_words('abcd')

# %% [markdown]
# ## We now have the building blocks to hack Letters and Numbers
#
#  1.) enter the letters into a python cell as a *string* and *assign* them a nickname
#
#  2.) Chuck that *string* of letters into our new magic doodad - all_words() (using it's nickname maybe?)
#
#  3.) Win Countdown!
#
#  Now try it for 'ABCDEFGHI'

# %%
# Enter the letters into python and assign them a nickname:

# %%
# Chuck that nickname into the all_words() function and see what happens!:

# %%
# input that nickname into a all_word():

# %% [markdown]
# ## Now lets play the gameshow!
